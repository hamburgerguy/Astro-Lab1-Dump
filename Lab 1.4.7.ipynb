# %%
import ugradio
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

# %% [markdown]
# # 4.7.1

# %%
x = ugradio.pico.capture_data('1V', nsamples=16000)
np.savetxt('data_1.0', x)

# %% [markdown]
# ## Mean Voltage, Mean Square Voltage, and Root-Mean-Square Voltage

# %%
x = np.loadtxt('data_1.0')

m = np.mean(x)
ms = np.mean(x**2)
rms = np.sqrt(np.mean(x**2))
print 'Mean Voltage: ', m, ', Mean Square Voltage: ', ms, ', Root-Mean-Square Voltage: ', rms
# Out:
# Mean Voltage:  60.736 , Mean Square Voltage:  193495.04 , Root-Mean-Square Voltage:  439.880711102

# %% [markdown]
# # 4.7.2

# %% [markdown]
# ## Histogram of Sampled Voltages

# %%
x = np.loadtxt('data_1.0')

plt.hist(x)
plt.title ('Histogram of Sampled Voltages')
plt.ylabel('Voltage')

x = np.linspace(-2000,2000)

pdf = norm.pdf(x,loc=m,scale=500)

plt.plot(x, 5625000*pdf, 'r-')
plt.show()

# %% [markdown]
# # 4.7.3

# %%
x = ugradio.pico.capture_data('1V', nsamples=16000, nblocks=32)
np.savetxt('data_1.1', x)

# %% [markdown]
# ## Power Spectra of All Blocks

# %%
# block 1

x = np.loadtxt('data_1.1')

f, fx = ugradio.dft.dft(x[0:15999])
P = fx*np.conj(fx)
plt.plot(P)
plt.title('Power Spectrum of Block 1')
plt.show()

m1 = np.mean(P)

# %%
# block 2

x = np.loadtxt('data_1.1')

f, fx = ugradio.dft.dft(x[16000:31999])
P = fx*np.conj(fx)

m2 = np.mean(P)

# %%
# block 3

x = np.loadtxt('data_1.1')

f, fx = ugradio.dft.dft(x[32000:47999])
P = fx*np.conj(fx)

m3 = np.mean(P)

# %%
# block 4

x = np.loadtxt('data_1.1')

f, fx = ugradio.dft.dft(x[48000:63999])
P = fx*np.conj(fx)

m4 = np.mean(P)

# %%
# block 5

x = np.loadtxt('data_1.1')

f, fx = ugradio.dft.dft(x[64000:79999])
P = fx*np.conj(fx)

m5 = np.mean(P)

# %%
# block 6

x = np.loadtxt('data_1.1')

f, fx = ugradio.dft.dft(x[80000:95999])
P = fx*np.conj(fx)

m6 = np.mean(P)

# %%
# block 7

x = np.loadtxt('data_1.1')

f, fx = ugradio.dft.dft(x[96000:111999])
P = fx*np.conj(fx)

m7 = np.mean(P)

# %%
# block 8

x = np.loadtxt('data_1.1')

f, fx = ugradio.dft.dft(x[112000:127999])
P = fx*np.conj(fx)

m8 = np.mean(P)

# %%
# block 9

x = np.loadtxt('data_1.1')

f, fx = ugradio.dft.dft(x[128000:143999])
P = fx*np.conj(fx)

m9 = np.mean(P)

# %%
# block 10

x = np.loadtxt('data_1.1')

f, fx = ugradio.dft.dft(x[144000:159999])
P = fx*np.conj(fx)

m10 = np.mean(P)

# %%
# block 11

x = np.loadtxt('data_1.1')

f, fx = ugradio.dft.dft(x[160000:175999])
P = fx*np.conj(fx)

m11 = np.mean(P)

# %%
# block 12

x = np.loadtxt('data_1.1')

f, fx = ugradio.dft.dft(x[176000:191999])
P = fx*np.conj(fx)

m12 = np.mean(P)

# %%
# block 13

x = np.loadtxt('data_1.1')

f, fx = ugradio.dft.dft(x[192000:207999])
P = fx*np.conj(fx)

m13 = np.mean(P)

# %%
# block 14

x = np.loadtxt('data_1.1')

f, fx = ugradio.dft.dft(x[208000:223999])
P = fx*np.conj(fx)

m14 = np.mean(P)

# %%
# block 15

x = np.loadtxt('data_1.1')

f, fx = ugradio.dft.dft(x[224000:239999])
P = fx*np.conj(fx)

m15 = np.mean(P)

# %%
# block 16

x = np.loadtxt('data_1.1')

f, fx = ugradio.dft.dft(x[240000:255999])
P = fx*np.conj(fx)

m16 = np.mean(P)

# %%
# block 17

x = np.loadtxt('data_1.1')

f, fx = ugradio.dft.dft(x[256000:271999])
P = fx*np.conj(fx)

m17 = np.mean(P)

# %%
# block 18

x = np.loadtxt('data_1.1')

f, fx = ugradio.dft.dft(x[272000:287999])
P = fx*np.conj(fx)

m18 = np.mean(P)

# %%
# block 19

x = np.loadtxt('data_1.1')

f, fx = ugradio.dft.dft(x[288000:303999])
P = fx*np.conj(fx)

m19 = np.mean(P)

# %%
# block 20

x = np.loadtxt('data_1.1')

f, fx = ugradio.dft.dft(x[304000:319999])
P = fx*np.conj(fx)

m20 = np.mean(P)

# %%
# block 21

x = np.loadtxt('data_1.1')

f, fx = ugradio.dft.dft(x[320000:335999])
P = fx*np.conj(fx)

m21 = np.mean(P)

# %%
# block 22

x = np.loadtxt('data_1.1')

f, fx = ugradio.dft.dft(x[336000:351999])
P = fx*np.conj(fx)

m22 = np.mean(P)

# %%
# block 23

x = np.loadtxt('data_1.1')

f, fx = ugradio.dft.dft(x[352000:367999])
P = fx*np.conj(fx)

m23 = np.mean(P)

# %%
# block 24

x = np.loadtxt('data_1.1')

f, fx = ugradio.dft.dft(x[368000:383999])
P = fx*np.conj(fx)

m24 = np.mean(P)

# %%
# block 25

x = np.loadtxt('data_1.1')

f, fx = ugradio.dft.dft(x[384000:399999])
P = fx*np.conj(fx)

m25 = np.mean(P)

# %%
# block 26

x = np.loadtxt('data_1.1')

f, fx = ugradio.dft.dft(x[400000:415999])
P = fx*np.conj(fx)

m26 = np.mean(P)

# %%
# block 27

x = np.loadtxt('data_1.1')

f, fx = ugradio.dft.dft(x[416000:431999])
P = fx*np.conj(fx)

m27 = np.mean(P)

# %%
# block 28

x = np.loadtxt('data_1.1')

f, fx = ugradio.dft.dft(x[432000:447999])
P = fx*np.conj(fx)

m28 = np.mean(P)

# %%
# block 29

x = np.loadtxt('data_1.1')

f, fx = ugradio.dft.dft(x[448000:463999])
P = fx*np.conj(fx)

m29 = np.mean(P)

# %%
# block 30

x = np.loadtxt('data_1.1')

f, fx = ugradio.dft.dft(x[464000:479999])
P = fx*np.conj(fx)

m30 = np.mean(P)

# %%
# block 31

x = np.loadtxt('data_1.1')

f, fx = ugradio.dft.dft(x[480000:495999])
P = fx*np.conj(fx)

m31 = np.mean(P)

# %%
# block 32

x = np.loadtxt('data_1.1')

f, fx = ugradio.dft.dft(x[496000:511999])
P = fx*np.conj(fx)

m32 = np.mean(P)

# %% [markdown]
# ## Power Spectra Averages

# %%
# power spectrum averages

y = np.array([m1, m2, m3, m4, m5, m6, m7, m8, m9, m10, m11, m12, m13, m14, m15, m16, m17, m18, m19, m20, m21, m22, m23, m24, m25, m26, m27, m28, m29, m30, m31, m32])
plt.plot(y)
plt.title('Power Spectra Averages')
plt.show()

# total power spectra average

Y = np.mean(y)
print 'Total average:', Y
# Out:
# Total average: (3117643776+0j)

# %% [markdown]
# # 4.7.4

# %% [markdown]
# ## Power Spectrum of Block 1

# %%
# block 1

x = np.loadtxt('data_1.1')

f, fx = ugradio.dft.dft(x[0:15999])
P = fx*np.conj(fx)
plt.plot(P)
plt.title('Power Spectrum of Block 1')
plt.show()

# %% [markdown]
# ## Power Spectra of N Blocks

# %%
# N=2

x = np.loadtxt('data_1.1')

f, fx = ugradio.dft.dft(x[0:31999])
P = fx*np.conj(fx)
plt.plot(P)
plt.title('Power Spectrum of N=2 Blocks')
plt.show()
# Out:
# /usr/local/lib/python2.7/dist-packages/numpy/core/numeric.py:531: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)

# %%
# N=4

x = np.loadtxt('data_1.1')

f, fx = ugradio.dft.dft(x[0:63999])
P = fx*np.conj(fx)
plt.plot(P)
plt.title('Power Spectrum of N=4 Blocks')
plt.show()

# %%
# N=8

x = np.loadtxt('data_1.1')

f, fx = ugradio.dft.dft(x[0:127999])
P = fx*np.conj(fx)
plt.plot(P)
plt.title('Power Spectrum of N=8 Blocks')
plt.show()

# %%
# N=16

x = np.loadtxt('data_1.1')

f, fx = ugradio.dft.dft(x[0:255999])
P = fx*np.conj(fx)
plt.plot(P)
plt.title('Power Spectrum of N=16 Blocks')
plt.show()

# %% [markdown]
# # 4.7.5

# %% [markdown]
# ## ACF of Block 1

# %%
# acf of block 1

data = np.loadtxt('data_1.1')
x = data[0:15999]
acf = np.correlate(x, x, mode='same')

# %%
# power spectrum derived from acf

f, fx = ugradio.dft.dft(acf)
Pacf = fx*np.conj(fx)

plt.plot(Pacf)
plt.title('Power Spectrum of ACF')
plt.show()

# %% [markdown]
# ## FWHM of ACF

# %%
from scipy.interpolate import UnivariateSpline

y = acf / acf.max() * 10
x = np.arange(1, 16000)

spline = UnivariateSpline(x,y-5,s=0)
Tfwhm = abs(spline.roots()[1]-spline.roots()[0])
print(Tfwhm)
# Out:
# 1.05900397081

# %% [markdown]
# ## FWHM of Power Spectrum

# %%
from scipy.interpolate import UnivariateSpline

x = np.loadtxt('data_1.1')

f, fx = ugradio.dft.idft(x[0:15999])
P = fx*np.conj(fx)

y = P / P.max() * 10
z = np.arange(1, 16000)

spline = UnivariateSpline(z,y-5,s=0)
Ffwhm = abs(spline.roots()[1]-spline.roots()[0])
print(Ffwhm)
# Out:
# 2.07358866152
# /usr/local/lib/python2.7/dist-packages/scipy-1.0.0rc1-py2.7-linux-x86_64.egg/scipy/interpolate/fitpack2.py:185: ComplexWarning: Casting complex values to real discards the imaginary part
#   xb=bbox[0],xe=bbox[1],s=s)

# %% [markdown]
# The FWHM of the ACF and that of the power spectrum are not identical, but they are of comparable magnitudes.
